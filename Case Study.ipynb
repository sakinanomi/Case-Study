# %%
import pandas as pd

# %%
df=pd.read_excel('superstore_sales.xlsx')
df.head(20)
# Out:
#            order_id order_date  ship_date       ship_mode      customer_name  \
# 0      AG-2011-2040 2011-01-01 2011-01-06  Standard Class    Toby Braunhardt
# 1     IN-2011-47883 2011-01-01 2011-01-08  Standard Class        Joseph Holt
# 2      HU-2011-1220 2011-01-01 2011-01-05    Second Class      Annie Thurman
# 3   IT-2011-3647632 2011-01-01 2011-01-05    Second Class       Eugene Moren
# 4     IN-2011-47883 2011-01-01 2011-01-08  Standard Class        Joseph Holt
# 5     IN-2011-47883 2011-01-01 2011-01-08  Standard Class        Joseph Holt
# 6      CA-2011-1510 2011-01-02 2011-01-06  Standard Class    Magdelene Morse
# 7     IN-2011-79397 2011-01-03 2011-01-03        Same Day        Kean Nguyen
# 8     ID-2011-80230 2011-01-03 2011-01-09  Standard Class       Ken Lonsdale
# 9      IZ-2011-4680 2011-01-03 2011-01-07  Standard Class   Lindsay Williams
# 10    IN-2011-65159 2011-01-03 2011-01-07    Second Class       Larry Blacks
# ...

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.size
# Out:
# 1077090

# %% [markdown]
# #### counting the nulls in each column

# %%
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# ship_date           0
# ship_mode          36
# customer_name       0
# segment             0
# state               0
# country             0
# market              0
# region              0
# product_id          0
# category            0
# sub_category        0
# product_name        0
# sales               0
# quantity           31
# discount          188
# profit              0
# shipping_cost       0
# order_priority     13
# year                0
# dtype: int64

# %% [markdown]
# #### counting nulls in total

# %%
df.isnull().sum().sum()
# Out:
# 268

# %% [markdown]
# ### Study the shipmode column

# %%
df.ship_mode.head()
# Out:
# 0    Standard Class
# 1    Standard Class
# 2      Second Class
# 3      Second Class
# 4    Standard Class
# Name: ship_mode, dtype: object

# %%
df.ship_mode.unique()
# Out:
# array(['Standard Class', 'Second Class', 'Same Day', nan, 'First Class'],
#       dtype=object)

# %%
df['ship_mode'].value_counts()
# Out:
# Standard Class    30739
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: ship_mode, dtype: int64

# %%
## since the majority are standard we fill na with standard
df['ship_mode'].fillna('Standard Class',inplace=True)

# %%
df['ship_mode']
# Out:
# 0        Standard Class
# 1        Standard Class
# 2          Second Class
# 3          Second Class
# 4        Standard Class
#               ...
# 51285    Standard Class
# 51286    Standard Class
# 51287      Second Class
# 51288    Standard Class
# 51289    Standard Class
# Name: ship_mode, Length: 51290, dtype: object

# %%
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# ship_date           0
# ship_mode           0
# customer_name       0
# segment             0
# state               0
# country             0
# market              0
# region              0
# product_id          0
# category            0
# sub_category        0
# product_name        0
# sales               0
# quantity           31
# discount          188
# profit              0
# shipping_cost       0
# order_priority     13
# year                0
# dtype: int64

# %% [markdown]
# ### Now quantity

# %%
df.quantity.unique()
# Out:
# array([ 2.,  3.,  4.,  5., nan,  1.,  7.,  6.,  8.,  9., 10., 11., 12.,
#        14., 13.])

# %%
df.quantity.value_counts()
# Out:
# 2.0     12748
# 3.0      9682
# 1.0      8932
# 4.0      6385
# 5.0      4882
# 6.0      3020
# 7.0      2385
# 8.0      1361
# 9.0       987
# 10.0      276
# 14.0      186
# 12.0      176
# 11.0      156
# 13.0       83
# Name: quantity, dtype: int64

# %%
## since 1 is the quantity we generally would not give importance to writing we fill na with 1

df.quantity.fillna(1,inplace=True)

# %% [markdown]
# ## Discount

# %%
df.discount.unique()
# Out:
# array([0.   , 0.1  ,   nan, 0.5  , 0.4  , 0.45 , 0.55 , 0.47 , 0.002,
#        0.6  , 0.2  , 0.8  , 0.17 , 0.25 , 0.7  , 0.402, 0.35 , 0.27 ,
#        0.15 , 0.37 , 0.65 , 0.3  , 0.15 , 0.07 , 0.602, 0.32 , 0.202,
#        0.57 , 0.85 , 0.45 ])

# %%
df.discount.value_counts()
# Out:
# 0.000    28821
# 0.200     4998
# 0.100     4068
# 0.400     3177
# 0.600     2006
# 0.700     1786
# 0.500     1633
# 0.170      735
# 0.470      725
# 0.002      461
# 0.150      459
# 0.270      388
# 0.300      340
# 0.450      325
# 0.800      316
# 0.250      198
# 0.070      150
# 0.350      122
# 0.402      104
# 0.150       82
# 0.370       74
# 0.202       41
# 0.320       27
# 0.602       23
# 0.650       17
# 0.570       12
# 0.550       10
# 0.850        2
# 0.450        2
# Name: discount, dtype: int64

# %%
## since 0 is the most frequent also 0 values are often tended to not to be written we fill na as 0

df.discount.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# order_id           0
# order_date         0
# ship_date          0
# ship_mode          0
# customer_name      0
# segment            0
# state              0
# country            0
# market             0
# region             0
# product_id         0
# category           0
# sub_category       0
# product_name       0
# sales              0
# quantity           0
# discount           0
# profit             0
# shipping_cost      0
# order_priority    13
# year               0
# dtype: int64

# %% [markdown]
# ### Order Priority

# %%
df.order_priority.unique()
# Out:
# array(['Medium', 'High', 'Critical', nan, 'Low'], dtype=object)

# %%
df.order_priority.value_counts()
# Out:
# Medium      29433
# High        15501
# Critical     3932
# Low          2411
# Name: order_priority, dtype: int64

# %%
## since most orders will be given medium order priority we fill na
df.order_priority.fillna('Medium',inplace=True)

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %% [markdown]
# ## The Dataset is free of null

# %%
df.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# ...

# %% [markdown]
# ## Maximum things are sold in which month

# %%
type(df.order_date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
months= df.groupby(df['order_date'].dt.to_period('M'))
months.mean()
# Out:
#                  sales  quantity  discount     profit  shipping_cost    year
# order_date
# 2011-01     228.402977  3.378753  0.158794  19.218940      24.352859  2011.0
# 2011-02     241.143272  3.238095  0.138233  32.851606      28.257045  2011.0
# 2011-03     270.369884  3.406308  0.137685  28.392520      24.297190  2011.0
# 2011-04     207.297454  3.581560  0.143230  22.876462      22.969007  2011.0
# 2011-05     259.271795  3.556537  0.145551  21.526199      29.051601  2011.0
# 2011-06     234.686347  3.393675  0.173974  25.534621      25.968494  2011.0
# 2011-07     233.354382  3.583838  0.161790  11.282835      23.928234  2011.0
# 2011-08     236.425389  3.456720  0.138339  27.008733      25.058241  2011.0
# 2011-09     275.869254  3.523764  0.130873  34.008445      28.198528  2011.0
# 2011-10     257.198016  3.523256  0.142367  33.544468      27.622845  2011.0
# 2011-11     262.068953  3.546093  0.157011  28.717452      30.467075  2011.0
# ...

# %%
def getMonth(s):
  return s.split("-")[1]

df.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# ...

# %%
df['month']=pd.Series(df['order_date'], dtype="string")##converting datetime to string

type(df['month'][0])
# Out:
# str

# %%
df['month']= df['month'].apply(lambda x: getMonth(x))#making a month column of the months

# %%
df.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
# ...

# %%
m=df.groupby('month')#grouping bu months
counts=m.quantity.count() #seeing how many things are sold sccording to month

# %%
counts.idxmax()#getting index of highest quantity
# Out:
# '11'

# %% [markdown]
# ### Thus we can say maximum amount of things are sold in November

# %% [markdown]
# ### Find the customer who has ordered most of the times

# %%
t=df.groupby('customer_name').quantity.count()
t
# Out:
# customer_name
# Aaron Bergman         89
# Aaron Hawkins         56
# Aaron Smayling        60
# Adam Bellavance       68
# Adam Hart             84
#                       ..
# Xylona Preis          61
# Yana Sorensen         62
# Yoseph Carroll        56
# Zuschuss Carroll      85
# Zuschuss Donatelli    54
# Name: quantity, Length: 795, dtype: int64

# %%
t['Toby Braunhardt']
# Out:
# 67

# %% [markdown]
# ### which year sales were the most

# %%
df.groupby('year').sales.count().idxmax()
# Out:
# 2014

# %%
df.groupby('year').sales.count().max()
# Out:
# 17531

# %%
df.groupby('year').sales.count().idxmin()
# Out:
# 2011

# %% [markdown]
# ### 2014 had the most sales

# %%
df.product_name.value_counts()
# Out:
# Staples                                                                      227
# Cardinal Index Tab, Clear                                                     92
# Eldon File Cart, Single Width                                                 90
# Rogers File Cart, Single Width                                                84
# Ibico Index Tab, Clear                                                        83
#                                                                             ...
# Xerox Blank Computer Paper                                                     1
# Panasonic KX MB2061 Multifunction Printer                                      1
# Grip Seal Envelopes                                                            1
# Snap-A-Way Black Print Carbonless Speed Message, No Reply Area, Duplicate      1
# Acco Glide Clips                                                               1
# Name: product_name, Length: 3788, dtype: int64

# %%
df.product_name.value_counts().idxmax()
# Out:
# 'Staples'

# %%
### Grouping the items according to year

df.groupby('year').product_name.value_counts()
# Out:
# year  product_name
# 2011  Staples                                                                                                55
#       Ibico Index Tab, Clear                                                                                 18
#       Smead Trays, Blue                                                                                      16
#       Acco Index Tab, Clear                                                                                  15
#       Binney & Smith Pencil Sharpener, Water Color                                                           15
#                                                                                                              ..
# 2014  Xerox Parchment Paper, Recycled                                                                         1
#       XtraLife ClearVue Slant-D Ring Binders by Cardinal                                                      1
# ...

# %%
df.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
# ...

# %%
###  What is the average days between order date and ship date
temp=df[['order_date','ship_date']]
temp.head()
# Out:
#   order_date  ship_date
# 0 2011-01-01 2011-01-06
# 1 2011-01-01 2011-01-08
# 2 2011-01-01 2011-01-05
# 3 2011-01-01 2011-01-05
# 4 2011-01-01 2011-01-08

# %%
temp['diff'] = [int(i.days) for i in (temp.ship_date - temp.order_date)]

temp.head()
# Out:
# C:\Users\sakin\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#   order_date  ship_date  diff
# 0 2011-01-01 2011-01-06     5
# 1 2011-01-01 2011-01-08     7
# 2 2011-01-01 2011-01-05     4
# 3 2011-01-01 2011-01-05     4
# 4 2011-01-01 2011-01-08     7

# %%
len(temp)
# Out:
# 51290

# %%
type(temp['diff'][0])
# Out:
# numpy.int64

# %%
temp['diff'].sum()/len(temp)
# Out:
# 3.96937024761162

# %% [markdown]
# ## Thus it takes 4 days in between order and shipping

# %% [markdown]
# ### Find the days between order and shipping for various kinds of ship_mode

# %%
temp=df[['order_date','ship_date','ship_mode']]
temp
# Out:
#       order_date  ship_date       ship_mode
# 0     2011-01-01 2011-01-06  Standard Class
# 1     2011-01-01 2011-01-08  Standard Class
# 2     2011-01-01 2011-01-05    Second Class
# 3     2011-01-01 2011-01-05    Second Class
# 4     2011-01-01 2011-01-08  Standard Class
# ...          ...        ...             ...
# 51285 2014-12-31 2015-01-04  Standard Class
# 51286 2014-12-31 2015-01-05  Standard Class
# 51287 2014-12-31 2015-01-02    Second Class
# 51288 2014-12-31 2015-01-06  Standard Class
# 51289 2014-12-31 2015-01-04  Standard Class
#
# [51290 rows x 3 columns]

# %%
temp['diff']=[int(i.days) for i in (temp.ship_date - temp.order_date)]
# Out:
# C:\Users\sakin\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
temp
# Out:
#       order_date  ship_date       ship_mode  diff
# 0     2011-01-01 2011-01-06  Standard Class     5
# 1     2011-01-01 2011-01-08  Standard Class     7
# 2     2011-01-01 2011-01-05    Second Class     4
# 3     2011-01-01 2011-01-05    Second Class     4
# 4     2011-01-01 2011-01-08  Standard Class     7
# ...          ...        ...             ...   ...
# 51285 2014-12-31 2015-01-04  Standard Class     4
# 51286 2014-12-31 2015-01-05  Standard Class     5
# 51287 2014-12-31 2015-01-02    Second Class     2
# 51288 2014-12-31 2015-01-06  Standard Class     6
# 51289 2014-12-31 2015-01-04  Standard Class     4
#
# [51290 rows x 4 columns]

# %%
grouped=temp.groupby('ship_mode').mean()
grouped
# Out:
#                     diff
# ship_mode
# First Class     2.181746
# Same Day        0.037394
# Second Class    3.230187
# Standard Class  4.998018

# %%
type(grouped)
# Out:
# pandas.core.frame.DataFrame

# %%
grouped.columns
# Out:
# Index(['diff'], dtype='object')

# %%
grouped['diff']
# Out:
# ship_mode
# First Class       2.181746
# Same Day          0.037394
# Second Class      3.230187
# Standard Class    4.998018
# Name: diff, dtype: float64

# %%
g=temp.groupby('ship_mode')
g['diff'].mean()
# Out:
# ship_mode
# First Class       2.181746
# Same Day          0.037394
# Second Class      3.230187
# Standard Class    4.998018
# Name: diff, dtype: float64

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(grouped)

# %% [markdown]
# ## Here we have shown the graph of average of number of days required by various shipping mode

# %% [markdown]
# #### more questions....

# %%
df
# Out:
#               order_id order_date  ship_date       ship_mode  \
# 0         AG-2011-2040 2011-01-01 2011-01-06  Standard Class
# 1        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# 2         HU-2011-1220 2011-01-01 2011-01-05    Second Class
# 3      IT-2011-3647632 2011-01-01 2011-01-05    Second Class
# 4        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# ...                ...        ...        ...             ...
# 51285   CA-2014-115427 2014-12-31 2015-01-04  Standard Class
# 51286     MO-2014-2560 2014-12-31 2015-01-05  Standard Class
# 51287   MX-2014-110527 2014-12-31 2015-01-02    Second Class
# 51288   MX-2014-114783 2014-12-31 2015-01-06  Standard Class
# 51289   CA-2014-156720 2014-12-31 2015-01-04  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [markdown]
# ### Which country gives the most sales

# %%
temp=df[['country','sales']]
temp.head()
# Out:
#      country    sales
# 0    Algeria  408.300
# 1  Australia  120.366
# 2    Hungary   66.120
# 3     Sweden   44.865
# 4  Australia  113.670

# %%
agg=temp.groupby('country').count()

# %%
len(agg)
# Out:
# 147

# %%
agg.sales.idxmax()
# Out:
# 'United States'

# %% [markdown]
# ### Plotting the sales as histogram

# %%
plt.hist(temp.sales)
# Out:
# (array([5.075e+04, 4.800e+02, 4.400e+01, 8.000e+00, 5.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([4.44000000e-01, 2.26424760e+03, 4.52805120e+03, 6.79185480e+03,
#         9.05565840e+03, 1.13194620e+04, 1.35832656e+04, 1.58470692e+04,
#         1.81108728e+04, 2.03746764e+04, 2.26384800e+04]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Discounts based on month

# %%
temp=df[['discount','month']]
temp.head()
# Out:
#    discount month
# 0       0.0    01
# 1       0.1    01
# 2       0.0    01
# 3       0.5    01
# 4       0.1    01

# %%
dis_agg=temp.groupby('month').discount.sum()

# %%
dis_agg.head(12)
# Out:
# month
# 01    362.582
# 02    304.174
# 03    432.294
# 04    454.146
# 05    538.732
# 06    792.922
# 07    473.646
# 08    677.940
# 09    819.516
# 10    640.670
# 11    914.412
# 12    918.694
# Name: discount, dtype: float64

# %%
type(dis_agg)
# Out:
# pandas.core.series.Series

# %%
dis_agg=pd.DataFrame(dis_agg)
dis_agg.head()
# Out:
#        discount
# month
# 01      362.582
# 02      304.174
# 03      432.294
# 04      454.146
# 05      538.732

# %%
dis_agg.columns
# Out:
# Index(['discount'], dtype='object')

# %%
dis_agg.index
# Out:
# Index(['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12'], dtype='object', name='month')

# %%
type(dis_agg)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(dis_agg.index,dis_agg.discount)

# %% [markdown]
# ### Maximun discounts are offered in November and December

# %% [markdown]
# ### trying to see the segments columns and study it

# %%
df.segment.unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df.segment.value_counts()
# Out:
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: segment, dtype: int64

# %% [markdown]
# ## Lets see which country has what kind of demand meaning country wise sales of consumer,corporate,home office goods

# %%
temp=df[['segment','country']]
temp.head()
# Out:
#        segment    country
# 0     Consumer    Algeria
# 1     Consumer  Australia
# 2     Consumer    Hungary
# 3  Home Office     Sweden
# 4     Consumer  Australia

# %%
temp.columns
# Out:
# Index(['segment', 'country'], dtype='object')

# %%
g=temp.groupby('country')

# %%
for count,segment in g:
    print(count)
    print(segment)
# Out:
# Afghanistan
#            segment      country
# 1443     Corporate  Afghanistan
# 1446     Corporate  Afghanistan
# 1454     Corporate  Afghanistan
# 1457     Corporate  Afghanistan
# 1466     Corporate  Afghanistan
# 3880     Corporate  Afghanistan
# 4369     Corporate  Afghanistan
# 7744      Consumer  Afghanistan
# 8183   Home Office  Afghanistan
# 11027    Corporate  Afghanistan
# 12266    Corporate  Afghanistan
# 12272    Corporate  Afghanistan
# 12276    Corporate  Afghanistan
# 12281    Corporate  Afghanistan
# 15010     Consumer  Afghanistan
# 15018     Consumer  Afghanistan
# 16150     Consumer  Afghanistan
# 16154     Consumer  Afghanistan
# 16190     Consumer  Afghanistan
# 16201     Consumer  Afghanistan
# 19283    Corporate  Afghanistan
# 19285    Corporate  Afghanistan
# 19286    Corporate  Afghanistan
# 19288    Corporate  Afghanistan
# 20360    Corporate  Afghanistan
# 20361    Corporate  Afghanistan
# 28643  Home Office  Afghanistan
# 28672  Home Office  Afghanistan
# ...

# %%
g.get_group('Benin')
# Out:
#            segment country
# 402      Corporate   Benin
# 1881     Corporate   Benin
# 5443      Consumer   Benin
# 5447      Consumer   Benin
# 5466      Consumer   Benin
# 6792     Corporate   Benin
# 6815     Corporate   Benin
# 10968     Consumer   Benin
# 13242     Consumer   Benin
# 15286     Consumer   Benin
# 18122    Corporate   Benin
# 18141    Corporate   Benin
# 26421     Consumer   Benin
# 27491    Corporate   Benin
# 27497    Corporate   Benin
# 27499    Corporate   Benin
# 28988     Consumer   Benin
# 32008    Corporate   Benin
# 32013    Corporate   Benin
# 32039    Corporate   Benin
# 32048    Corporate   Benin
# 32066    Corporate   Benin
# 33665    Corporate   Benin
# 33666    Corporate   Benin
# 34860    Corporate   Benin
# 35424    Corporate   Benin
# 35678  Home Office   Benin
# 38934    Corporate   Benin
# 38942    Corporate   Benin
# 39557     Consumer   Benin
# 43673    Corporate   Benin
# 44681    Corporate   Benin
# 48886     Consumer   Benin
# ...

# %%
temp=df[['segment','country','quantity']]
temp.head()
# Out:
#        segment    country  quantity
# 0     Consumer    Algeria       2.0
# 1     Consumer  Australia       3.0
# 2     Consumer    Hungary       4.0
# 3  Home Office     Sweden       3.0
# 4     Consumer  Australia       5.0

# %%
g=temp.groupby(['country','segment'])

# %%
fin=g.quantity.sum()

# %%
type(fin)
# Out:
# pandas.core.series.Series

# %%
fin=pd.DataFrame(fin)

# %%
type(fin)
# Out:
# pandas.core.frame.DataFrame

# %%
fin.columns
# Out:
# Index(['quantity'], dtype='object')

# %%
fin.head()
# Out:
#                          quantity
# country     segment
# Afghanistan Consumer         70.0
#             Corporate       132.0
#             Home Office      26.0
# Albania     Consumer         13.0
#             Corporate        23.0

# %%
fin.index
# Out:
# MultiIndex([('Afghanistan',    'Consumer'),
#             ('Afghanistan',   'Corporate'),
#             ('Afghanistan', 'Home Office'),
#             (    'Albania',    'Consumer'),
#             (    'Albania',   'Corporate'),
#             (    'Albania', 'Home Office'),
#             (    'Algeria',    'Consumer'),
#             (    'Algeria',   'Corporate'),
#             (    'Algeria', 'Home Office'),
#             (     'Angola',    'Consumer'),
#             ...
#             (    'Vietnam', 'Home Office'),
#             (      'Yemen',    'Consumer'),
#             (      'Yemen',   'Corporate'),
#             (      'Yemen', 'Home Office'),
#             (     'Zambia',    'Consumer'),
#             (     'Zambia',   'Corporate'),
#             (     'Zambia', 'Home Office'),
#             (   'Zimbabwe',    'Consumer'),
#             (   'Zimbabwe',   'Corporate'),
#             (   'Zimbabwe', 'Home Office')],
#            names=['country', 'segment'], length=408)

# %%
fin.loc['Afghanistan']
# Out:
#              quantity
# segment
# Consumer         70.0
# Corporate       132.0
# Home Office      26.0

# %%
fin.loc['Afghanistan'].columns
# Out:
# Index(['quantity'], dtype='object')

# %%
plt.bar(fin.loc['Afghanistan'].index,fin.loc['Afghanistan'].quantity)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### Enter the country whose distribution you want to see

# %%
ans=input('Enter a country')
# Out:
# Enter a countryAfghanistan

# %%
plt.bar(fin.loc[ans].index,fin.loc[ans].quantity)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### The bar diagram shows the amount of type of goods in the country entered

# %%
df
# Out:
#               order_id order_date  ship_date       ship_mode  \
# 0         AG-2011-2040 2011-01-01 2011-01-06  Standard Class
# 1        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# 2         HU-2011-1220 2011-01-01 2011-01-05    Second Class
# 3      IT-2011-3647632 2011-01-01 2011-01-05    Second Class
# 4        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# ...                ...        ...        ...             ...
# 51285   CA-2014-115427 2014-12-31 2015-01-04  Standard Class
# 51286     MO-2014-2560 2014-12-31 2015-01-05  Standard Class
# 51287   MX-2014-110527 2014-12-31 2015-01-02    Second Class
# 51288   MX-2014-114783 2014-12-31 2015-01-06  Standard Class
# 51289   CA-2014-156720 2014-12-31 2015-01-04  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.sub_category.unique()
# Out:
# array(['Storage', 'Supplies', 'Paper', 'Furnishings', 'Machines',
#        'Appliances', 'Copiers', 'Chairs', 'Tables', 'Bookcases', 'Phones',
#        'Accessories', 'Labels', 'Art', 'Envelopes', 'Fasteners',
#        'Binders'], dtype=object)

# %%
df.sub_category.value_counts()
# Out:
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: sub_category, dtype: int64
